# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Load the dataset
data = pd.read_csv('dataset2.csv')
X = data.iloc[:, :-1].values  # Features (Arm length, Ball weight, etc.)
y = data.iloc[:, -1].values   # Target (1 = hit, 0 = miss)

# Normalize the features
offsets = X.mean(axis=0)
scales = X.std(axis=0)
X_scaled = (X - offsets) / scales

# Convert target to categorical (two outputs: miss [0], hit [1])
y_categorical = to_categorical(y, num_classes=2)

# Define the neural network model
model = Sequential([
    Input(shape=(6,)),                     
    Dense(20, activation='relu'),          
    Dense(15, activation='tanh'),          
    Dense(10, activation='tanh'),           
    Dense(2, activation='softmax')         
])

# Compile the model
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Use early stopping to avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
model.fit(X_scaled, y_categorical, epochs=300, batch_size=32, verbose=1)

# Save the model and scaling parameters  
model.save(f'rb1424-2.keras')

# Save the scaling parameters
scaling_array = np.vstack([offsets, scales]) 
np.savetxt(f'rb1424-2.txt', scaling_array)
# Out:
# Epoch 1/300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 861us/step - accuracy: 0.5170 - loss: 0.7317
# Epoch 2/300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.5660 - loss: 0.6845
# Epoch 3/300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.5816 - loss: 0.6744
# Epoch 4/300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.5813 - loss: 0.6735
# Epoch 5/300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.5947 - loss: 0.6626
# Epoch 6/300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.6067 - loss: 0.6590
# Epoch 7/300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - accuracy: 0.5985 - loss: 0.6587
# Epoch 8/300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.6171 - loss: 0.6427
# Epoch 9/300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.6247 - loss: 0.6472
# Epoch 10/300
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.6248 - loss: 0.6459
# Epoch 11/300
# ...
